# %% [markdown]
# <a href="https://colab.research.google.com/github/grendelaglaeca/natural_disaster_tweets/blob/main/disaster_tweet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#read data
df = pd.read_csv("train.csv")

# %%
#check the shape of this dataframe
df.shape
df
# Out:
#          id keyword  ...                                               text target
# 0         1     NaN  ...  Our Deeds are the Reason of this #earthquake M...      1
# 1         4     NaN  ...             Forest fire near La Ronge Sask. Canada      1
# 2         5     NaN  ...  All residents asked to 'shelter in place' are ...      1
# 3         6     NaN  ...  13,000 people receive #wildfires evacuation or...      1
# 4         7     NaN  ...  Just got sent this photo from Ruby #Alaska as ...      1
# ...     ...     ...  ...                                                ...    ...
# 7608  10869     NaN  ...  Two giant cranes holding a bridge collapse int...      1
# 7609  10870     NaN  ...  @aria_ahrary @TheTawniest The out of control w...      1
# 7610  10871     NaN  ...  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...      1
# 7611  10872     NaN  ...  Police investigating after an e-bike collided ...      1
# ...

# %%
#data exploration, take a look at specific tweets
texts = df['text']
len(texts)
texts
# Out:
# 0       Our Deeds are the Reason of this #earthquake M...
# 1                  Forest fire near La Ronge Sask. Canada
# 2       All residents asked to 'shelter in place' are ...
# 3       13,000 people receive #wildfires evacuation or...
# 4       Just got sent this photo from Ruby #Alaska as ...
#                               ...
# 7608    Two giant cranes holding a bridge collapse int...
# 7609    @aria_ahrary @TheTawniest The out of control w...
# 7610    M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...
# 7611    Police investigating after an e-bike collided ...
# 7612    The Latest: More Homes Razed by Northern Calif...
# Name: text, Length: 7613, dtype: object

# %%
#data exploration, continued
tweety = texts[6]
tweety
# Out:
# '#flood #disaster Heavy rain causes flash flooding of streets in Manitou, Colorado Springs areas'

# %%
#extract words from a particular tweet
words = tweety.split(' ')
len(words)
type(words)
words
# Out:
# ['#flood',
#  '#disaster',
#  'Heavy',
#  'rain',
#  'causes',
#  'flash',
#  'flooding',
#  'of',
#  'streets',
#  'in',
#  'Manitou,',
#  'Colorado',
#  'Springs',
#  'areas']

# %%
hashtags = []
for tweet in texts:
  words = tweet.split(' ')
  tags = [word for word in words if '#' in word]
  hashtags.append(tags)

#hashtags = [a for a in tweet.split(' ') for tweet in texts]
hashtags
# Out:
# [['#earthquake'],
#  [],
#  [],
#  ['#wildfires'],
#  ['#Alaska', '#wildfires'],
#  ['#RockyFire', '#CAfire', '#wildfires'],
#  ['#flood', '#disaster'],
#  [],
#  [],
#  [],
#  [],
#  ['#flooding'],
#  ['#raining', '#flooding', '#Florida', '#TampaBay', '#Tampa'],
#  ['#Flood', '#We'],
#  ['#BREAKING'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['#metal', '#RT'],
#  ['#AFRICANBAZE:'],
#  [],
#  [],
#  ['#mufc'],
#  [],
#  ['#Bridgetown'],
#  [],
#  ['#nsfw'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['#nsfw'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['#Kurds', '#Diyala'],
#  [],
#  [],
#  [],
#  ['#California', '#climate', '#energy'],
#  [],
#  [],
#  [],
#  [],
#  ['#NowPlaying:', '#EDM'],
#  [],
#  [],
#  [],
#  ['#NashvilleTraffic.'],
#  ['#SantaClara', '#BayArea', '#Traffic'],
#  ['#personalinjury', '#solicitor', '#OtleyHour'],
#  ['#stlouis', '#caraccidentlawyer'],
#  [],
#  [],
# ...

# %%
#attach the hashtags to the dataframe as a new column
df['hashtags'] = hashtags
df
# Out:
#          id keyword  ... target               hashtags
# 0         1     NaN  ...      1          [#earthquake]
# 1         4     NaN  ...      1                     []
# 2         5     NaN  ...      1                     []
# 3         6     NaN  ...      1           [#wildfires]
# 4         7     NaN  ...      1  [#Alaska, #wildfires]
# ...     ...     ...  ...    ...                    ...
# 7608  10869     NaN  ...      1                     []
# 7609  10870     NaN  ...      1                     []
# 7610  10871     NaN  ...      1                     []
# 7611  10872     NaN  ...      1                     []
# 7612  10873     NaN  ...      1                     []
#
# [7613 rows x 6 columns]

# %%
#text replacement
tweet.replace('-', ' ')
tweet.upper()
tweet.lower()
tweet.capitalize()
tweet.swapcase()
# Out:
# 'tHE lATEST: mORE hOMES rAZED BY nORTHERN cALIFORNIA wILDFIRE - abc nEWS HTTP://T.CO/yMy4RsKq3D'

# %%
#preprocessing extract tweet and source separately
items = tweet.split('-')
print(items[0])
items[1]
# Out:
# The Latest: More Homes Razed by Northern California Wildfire
# ' ABC News http://t.co/YmY4rSkQ3d'

# %%
#remove whitespaces
items_clean = [item.strip() for item in items]
items_clean
# Out:
# ['The Latest: More Homes Razed by Northern California Wildfire',
#  'ABC News http://t.co/YmY4rSkQ3d']

# %%
#extract news source based on the assumption 
#that the news source occurs after a dash "-" 
#(which is not true but whatever)

news_source = []
for tweet in texts:
  if '-' in tweet:
    items = tweet.split('-')
    source = items[1]
    source = source.strip()
    news_source.append(source)
  else:
    news_source.append('[]')

df['news_source'] = news_source
df
# Out:
#          id  ...                                     news_source
# 0         1  ...                                              []
# 1         4  ...                                              []
# 2         5  ...                                              []
# 3         6  ...                                              []
# 4         7  ...                                              []
# ...     ...  ...                                             ...
# 7608  10869  ...                                              []
# 7609  10870  ...                                              []
# 7610  10871  ...                                              []
# 7611  10872  ...  bike collided with a car in Little Portugal. E
# 7612  10873  ...                 ABC News http://t.co/YmY4rSkQ3d
#
# [7613 rows x 7 columns]

# %% [markdown]
# **Use SpaCy to do depencency parsing and extract other linguistic features**

# %%
#import spacy.cli
#spacy.cli.download("en_core_web_sm")

# !pip install -U pip setuptools wheel
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# Out:
# ...
# 2021-03-07 19:02:14.613435: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ...
#      |████████████████████████████████| 13.7 MB 95 kB/s
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

#assign a sentence to parse
doc = nlp(tweety)

for token in doc:
  print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-67ec9b50b2d6> in <module>()
#       3
#       4 #assign a sentence to parse
# ----> 5 doc = nlp(tweety)
#       6
#       7 for token in doc:
#
# NameError: name 'tweety' is not defined
